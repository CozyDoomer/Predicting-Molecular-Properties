# %%
import os
import pandas as pd
import numpy as np

# %%
test = pd.read_csv('data/test.csv')
preds = pd.read_csv('message_passing_nn/data/submission/all_types_new_features/submit/submit-00055000_model-larger.csv')

# %%
COUPLING_TYPE_STATS = [
    # type   #mean, std, min, max
    '1JHC',  94.9761528641869,   18.27722399839607,   66.6008,   204.8800,
    '2JHC',  -0.2706244378832,    4.52360876732858,  -36.2186,    42.8192,
    '3JHC',   3.6884695895355,    3.07090647005439,  -18.5821,    76.0437,
    '1JHN',  47.4798844844683,   10.92204561670947,   24.3222,    80.4187,
    '2JHN',   3.1247536134185,    3.67345877025737,   -2.6209,    17.7436,
    '3JHN',   0.9907298624944,    1.31538940138001,   -3.1724,    10.9712,
    '2JHH', -10.2866051639817,    3.97960190019757,  -35.1761,    11.8542,
    '3JHH',   4.7710233597359,    3.70498129755812,   -3.0205,    17.4841,
]
NUM_COUPLING_TYPE = len(COUPLING_TYPE_STATS)//5

COUPLING_TYPE_MEAN = [COUPLING_TYPE_STATS[i*5+1] for i in range(NUM_COUPLING_TYPE)]
COUPLING_TYPE_STD = [COUPLING_TYPE_STATS[i*5+2] for i in range(NUM_COUPLING_TYPE)]

# %%
predict = []
for i, row in test.iterrows():
    if i % 10000 == 0: print(i)
    #truth = row.scalar_coupling_constant
    pred = preds.loc[i].scalar_coupling_constant
    types_mean = COUPLING_TYPE_MEAN[COUPLING_TYPE_STATS.index(row.type)//5]
    types_std = COUPLING_TYPE_STD[COUPLING_TYPE_STATS.index(row.type)//5]
    predict.append(pred * types_std + types_mean)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1030000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# ...

# %%
predict_compare = pd.read_csv(('message_passing_nn/data/submission/all_types_yukawa_radius_set2set/'
                               'submit/set2set_highbs_mpnn_larger_single.csv'))

# %%
np.mean(predict)
# Out:
# 15.850960256268957

# %%
np.mean(predict_compare.scalar_coupling_constant)
# Out:
# 15.877525952360596

# %%
test['scalar_coupling_constant'] = predict

# %%
test.head()
# Out:
#         id     molecule_name  atom_index_0  atom_index_1  type  \
# 0  4658147  dsgdb9nsd_000004             2             0  2JHC
# 1  4658148  dsgdb9nsd_000004             2             1  1JHC
# 2  4658149  dsgdb9nsd_000004             2             3  3JHH
# 3  4658150  dsgdb9nsd_000004             3             0  1JHC
# 4  4658151  dsgdb9nsd_000004             3             1  2JHC
#
#    scalar_coupling_constant
# 0                 15.284554
# 1                173.799427
# 2                  3.674762
# 3                173.799427
# 4                 15.284554

# %%
test[['id', 'scalar_coupling_constant']].to_csv('data/subs/testing_target_normalization.csv', index=False)
